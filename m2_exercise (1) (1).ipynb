# %% [markdown]
# # Module 2 Color Exercise
#
# **In these exercises, we will create plots with correct and adequate color schemes similar to the practice.**

# %%
library(ggplot2)
library(RColorBrewer)

# %% [markdown]
# **Activity 1:** Display colormaps with seven colors from RColorBrewer library for a **sequential** data type with **colorblind safe** colors.

# %%
## Your answer for activity 1 goes here ---

n = 7
display.brewer.pal(n, name = "Greens" )
display.brewer.all(n, type="seq", select=NULL, exact.n=TRUE, colorblindFriendly=TRUE)
# Out:
# plot without title
# plot without title

# %% [markdown]
# **Activity 2:** Create a **colorblind safe colormap with 100 colors** from the dichromat library, and display their hexadecimal codes.

# %%
library(dichromat)
## Your answer for activity 2 goes here ---

colorRampPalette(dichromat(100))(100)
# Out:
#   [1] "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5"
#   [8] "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5"
#  [15] "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5"
#  [22] "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5"
#  [29] "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5"
#  [36] "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5"
#  [43] "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5"
#  [50] "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5"
#  [57] "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5"
#  [64] "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5"
#  [71] "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5"
#  [78] "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5"
#  [85] "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5"
#  [92] "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5" "#8484E5"
#  [99] "#8484E5" "#8484E5"

# %% [markdown]
# **Activity 3:** Use ellipse library to create an elliptical correlation plot for the diamonds data using carat, price, table, and depth variables. Make sure to use a **colorblind safe, diverging** color scheme.

# %%
library(ellipse)
head(diamonds)
data=diamonds[,c("carat","depth","price","table")]

## Your answer for activity 3 goes here ---

c <- colorRampPalette(brewer.pal(5, "Spectral"))(100)

cor_data <- cor(data)
ord <- order(cor_data[1, ])
cor_data_ord <- cor_data[ord, ord]

plotcorr(
    cor_data_ord, 
    col=c[as.integer(cor_data_ord*50 + 50)], 
    mar=c(0,0,0,0))
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48
# plot without title

# %% [markdown]
# **Activity 4:** Create a scatter plot using **all** diamonds data for carat vs. price and encode `clarity` variable with a **sequential** color scheme.

# %%
gp <- (
    ggplot(diamonds) +
    aes(x=carat, y=price, color=clarity) +  # Encoding clarity variable with sequential color scheme
    geom_point(size=3)
)

(
    gp +
    scale_colour_brewer(palette = 'Greens') +
    theme(
        legend.title = element_text(size=20),
        legend.text = element_text(size=20),
        axis.title = element_text(size=20),
        axis.text = element_text(size=20)
    )
)
# Out:
# plot without title

# %% [markdown]
# **Activity 5:** Repeat Activity 4 with **alpha transparency**. **Is this a better idea? Discuss your answer.**

# %%
## Your answer for activity 5 goes here ---
gp <- (
    ggplot(diamonds) 
    + aes(x=carat, y=price, color=clarity)
    + geom_point(size=3,alpha = 0.5)
)
(
    gp 
    + scale_colour_brewer(palette = 'Greens')
    + theme(
        legend.title = element_text(size=20),
        legend.text = element_text(size=20),
        axis.title = element_text(size=20),
        axis.text = element_text(size=20),
    )
)
# hint: geom_point(alpha=0.5)
# Out:
# plot without title

# %% [markdown]
# **Activity 6:** Recreate the following plot using `ggplot2` functions and the **mtcars** data set.
#
# Hint: you may have to change attribute characteristics, also look at theme functions in `ggplot2`.
#
# ![ex.png](attachment:00550901-753c-4e9b-a971-71d00e25e17d.png)

# %%
# Load necessary libraries
library(ggplot2)

# Create the plot
ggplot(mtcars, aes(x = wt, y = mpg, color = factor(cyl), linetype = factor(cyl), size = qsec)) +
  geom_point(alpha = 0.5) +
  geom_smooth(aes(group = cyl),method = "lm",linetype = "solid") +
  labs(
       x = "wt",
       y = "mpg",
       color = "cyl",
       linetype = "cyl",
       size = "qsec") +
  guides(color = guide_legend(override.aes = list(size = 4), title = "cyl", keywidth = 2),
         linetype = guide_legend(override.aes = list(linetype = 1), title = "cyl", keywidth = 2),
         size = guide_legend(title = "qsec", keywidth = 1)) +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# "The following aesthetics were dropped during statistical transformation: size
# ℹ This can happen when ggplot fails to infer the correct grouping structure in the data.
# ℹ Did you forget to specify a `group` aesthetic or to convert a numerical variable into a factor?"
# plot without title
